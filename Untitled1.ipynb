# %%
2+4
# Out:
# 6

# %%
d=5.0
l=0.4
d*d*l
# Out:
# 10.0

# %% [markdown]
# # dssdfsd
#
# ## deneme
#
# ### sdsfds
#
# - fdsf
# - fdgds
# - gsdgds
#
# $$x^2 B_a = \int_0 = \dfrac{1}{\vec{B}}$$

# %%
d+3
# Out:
# 8.0
